# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/spotify_long_tracks_2014_2024.csv')

# %%
data
# Out:
#                          ID  \
# 0    026O2YP2wRl9h3Ht9ClZST
# 1    0DXnjJxJBvgMvBjG6Jug7I
# 2    6BFn78qFy9bRqKHTMfhnNv
# 3    1dNwMOMtq3yflXibbqgLku
# 4    290gfei8moWWSh8qTVkTT3
# ..                      ...
# 811  0OYbUI94jw0vLQeAmKKZ53
# 812  4Wmjr8wNvU4O3tj3CXRmkE
# 813  465EdPfedCDmofyICPGmiF
# 814  2NNBTCfzAgyolaaZNNzD4O
# 815  5dB5tmSZ4hoUY36tSkPoxt
#
#                                                   Name  Duration (Minutes)  \
# 0    Steady Rain in a Forest with Light Background ...                 100
# 1                                     Soundarya Lahari                  66
# 2                    Waves of Abundance & Fullfillment                  60
# 3    Mosquito Solution Anti Teen Street Party or Te...                  45
# 4    Ibiza Sunset Tibetan Singing Bowl Sessions 7 (...                  44
# ..                                                 ...                 ...
# 811                                            Keep On                   5
# 812                               雨の街 - Re:Lilly remix                   5
# 813                           Měla Jsem Vrásky Na Čele                   5
# 814                         ARIGATOUNO WA - Cover ver.                   5
# 815                                         Alt Barbat                   5
#
#                    Artists
# 0            Nature Sounds
# 1         Mambalam Sisters
# 2           Zen Life Relax
# 3      Device Sound Effect
# 4    Tibetan Singing Bowls
# ..                     ...
# 811                Vanilla
# 812               Re:Lilly
# 813        Jana Rychterová
# 814              Baby Band
# 815                Mellina
#
# [816 rows x 4 columns]

# %%
x = data[ID]
y = data[Duration]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-2f905729929c> in <cell line: 1>()
# ----> 1 x = data[ID]
#       2 y = data[Duration]
#
# NameError: name 'ID' is not defined

# %%
x = data.iloc[:,:-1].values

# %%
x
# Out:
# array([['026O2YP2wRl9h3Ht9ClZST',
#         'Steady Rain in a Forest with Light Background Bird Chirping (Storm Ambience Sound Effects)',
#         100],
#        ['0DXnjJxJBvgMvBjG6Jug7I', 'Soundarya Lahari', 66],
#        ['6BFn78qFy9bRqKHTMfhnNv', 'Waves of Abundance & Fullfillment',
#         60],
#        ...,
#        ['465EdPfedCDmofyICPGmiF', 'Měla Jsem Vrásky Na Čele', 5],
#        ['2NNBTCfzAgyolaaZNNzD4O', 'ARIGATOUNO WA - Cover ver.', 5],
#        ['5dB5tmSZ4hoUY36tSkPoxt', 'Alt Barbat', 5]], dtype=object)

# %%
y = data.iloc[:,-1].values

# %%
y
# Out:
# array(['Nature Sounds', 'Mambalam Sisters', 'Zen Life Relax',
#        'Device Sound Effect', 'Tibetan Singing Bowls', 'Gontaro Yanagiya',
#        'Pēteris Vasks, O/Modernt Chamber Orchestra, Hugo Ticciati',
#        'Jessica Cross', 'Relaxmydog',
#        "Nicole Lizée, Canada's National Arts Centre Orchestra, Alexander Shelley",
#        'LOKOS TV Now Meditation Music', 'Len Leise', 'Sapien Medicine',
#        'Nusrat Fateh Ali Khan', 'Al Sheikh Ahmad Alnufais',
#        'Utamaru Katsura', 'Tangerine Dream', 'Sun Ra',
#        'Felipe Pigna, Roberto Martínez', 'Edres Abkar', 'Satorio',
#        'Emmett Miller, Steven Halpern', 'Blue Claw Fitness', 'Tha Lero',
#        'Anton Bruckner, Bavarian Radio Symphony Orchestra, Otto Klemperer',
#        'Krishna Das, Sharon Salzberg', 'Katie Weatherup',
#        'Franz Schmidt, Wiener Philharmoniker, Zubin Mehta', 'S.E.T.I.',
#        'Luciano Berio, Institute for Computer Music and Sound Technology, Georg Kohler',
#        'Lucky Star no Minna', 'Ionela Pascu', 'Küçük Murat',
#        'Johann Nepomuk Hummel, Dieter Klöcker, Florian Uhlig, Consortium Classicum',
#        'Ludwig van Beethoven, Berliner Philharmoniker, Herbert von Karajan',
#        'Hatem Al Iraqi', 'Lucas King',
#        'Richard Wagner, Stuttgart Radio Symphony Orchestra, Hans Müller-Kray',
#        'Herman Basudde',
#        'Anton Bruckner, Wiener Philharmoniker, Herbert von Karajan',
#        'Hans Pfitzner, Rundfunk-Sinfonieorchester Berlin, Alban Gerhardt, Sebastian Weigle',
#        'Allegaeon',
#        'Antonín Dvořák, Alisa Weilerstein, Czech Philharmonic, Jiří Bělohlávek',
#        'Dimitri Murrath, Vincent Planès', 'Win Oo',
#        'Dmitry Kabalevsky, Torleif Thedéen, Hannover Radio Philharmonic Orchestra, Eiji Oue',
#        'Ludwig van Beethoven, The Beethoven Quartet', 'مكرم المنياوي',
#        'Bvdub', '妙蓮華', 'Kaipa', 'Skinnerbox', 'Sweet Carol',
#        'Zaïko Langa Langa, Nkolo Mboka', 'King of the World',
#        'Frédéric Chopin, Folke Nauta', 'Cheb Hichem', 'Macroform',
#        'Howard Givens, Craig Padilla', 'Dayspring Worship, Joel Wiseman',
#        'Wolfgang Amadeus Mozart, Les Vents Français', 'Musarra',
#        'Nora del Mar', 'Relaxing888', 'Arabic Djs, Arabic DJ',
#        'Ludwig van Beethoven, Ji Hae Park, Simon Lepper',
#        'Barry Jamieson', 'Kelly Andrew',
#        'Wolfgang Amadeus Mozart, Eduardo Marturet, Emmy Verhey, Royal Concertgebouw Orchestra',
#        'Oscar Navarro Gonzalez, Oscar Navarro, Oscar Navarro Symphony Orchestra',
#        'Endless Ocean', 'New Members',
#        'Lee Weisert, Clara Yang, Juan Alamo',
#        'Alberto Ginastera, Donald Sulzen, Henry Raudales',
#        'Jorgio Kioris, Simos Tagias, Hot Tuneik', '1 Mile North',
#        'Black Foxxes', 'Z-Arc',
#        'Carl Michael Ziehrer, Original C.M.Ziehrer Orchester, Hans Schadenbauer',
#        'George Banton', 'Mourners Lament', 'Loom, Dopadocks',
#        'Invisible Reality, Klopfgeister',
#        'Derya Türkan, Sokratis Sinopoulos', 'Bongo & Pusk',
#        'Dren McDonald', 'Cornershop',
#        'Glaubenszentrum Live, Markus Muntean',
#        "Claude Debussy, Orchestra dell'Accademia Nazionale di Santa Cecilia, Leonard Bernstein",
#        'Dzivia', 'Vous Autres', 'Alienn', 'Trey Anastasio',
#        'Alexa Sunshine Rose, Shimshai', 'Cyril', 'Andawan', 'Sanam Marvi',
#        'Drive-By Truckers',
#        'O.C., Fat Joe, Lord Finesse, Big L, A.G., Diamond D', 'Mindwave',
#        'Marimba Orquesta La Gran Manzana', 'yeahyoutoo', 'Dyce',
#        'Kyle Bobby Dunn', 'Causa Sui', 'Ali Krasniqi, Halil Bytyqi',
#        'Jean Sibelius, Turku Philharmonic Orchestra, Leif Segerstam',
#        'Alpha Gravity', 'Osvit', 'Matthew Fries, Phil Palombi',
#        'Orquesta Amor Latino', 'KHAIKHAN, Dest', 'Simon Le Grec',
#        'Mate Bulic', 'Andres Sanchez, Katherine Amy', 'Ivan Graziani',
#        'Antlers', 'Nusrat Fateh Ali Khan', 'Pspiralife', 'Metallica',
#        'Hossam Ramzy', 'Pascal Voggenhuber', 'Jacky Mingo, Kapote',
#        'Antonín Dvořák, Northern String Quartet', 'Crazy P',
#        'Harinama Ruci', 'Susheela Raman', 'Gazal Alabedallah',
#        'The Mansisters', 'Federico Scavo', 'Ricardo Piedra, Kay-D',
#        'Neptune Project, Polly Strange, The Noble Six',
#        'Antonín Dvořák, Budapest Philharmonic Orchestra, Stephen Pomerantz',
#        'Pyotr Ilyich Tchaikovsky, Philharmonia Orchestra, Sir Charles Mackerras',
#        'John Tavener, Andrew Lumsden, Winchester Cathedral Choir, George Castle',
#        'Miguel Zenón', 'Jimmy Dawkins', 'Tommy Castro', 'Mike Casey',
#        'Ralph Myerz, R.E.C., Ryan James, SUPER SPACE PROJECT',
#        'Róisín Murphy, Crooked Man', 'CHANDAN SHARMA HATHRASI',
#        'Depeche Mode', 'Héritier Wata', 'Spencer Parker', 'Andruss',
#        'FELIZ', 'Solarc, Criss Source', 'Funk You', 'Kamilo Sanclemente',
#        'Love From San Francisco', 'Traumton', 'Casimir Von Oettingen',
#        'ヒーリング・ライフ', 'Shai T', 'Rhyton', 'Uttam Kumar Mondal',
#        'Perception', 'Chromeo, Toro y Moi', 'Boy Next Door',
#        'Connie Harvey', 'Andres Blows', 'Sonu Sargam Yadav', 'Seol',
#        'Dominika Gurbaľová', 'North Coast Vibes, Rob G', 'Cristoph',
#        'Wolfgang Amadeus Mozart, Anna Maunther, Tatrai Quartet',
#        'Pablo Held Trio, Pablo Held, Robert Landfermann, Jonas Burgwinkel',
#        'Alessandro Penna',
#        'Golden Era Records, Hilltop Hoods, Funkoars, A.B. Original, Briggs, Vents, K21, Purpose',
#        'Edvard Grieg, Mikhail Pletnev', 'Shahrokh', 'Pragmatix',
#        'Antonio Venuti & Mr Goaty', 'Kayros, João Oliveira', 'Phase 2',
#        'Grateful Dead', 'DJ Tarkan', 'Alfoa', 'Stefano Noferini, Looad',
#        'Jason Bye', 'Ben DJ', 'Tony Anderson',
#        'Max Freegrant, Max Meyer, DJ San',
#        'Frank Donner, George Morel, Stefan Mint', 'Birdcage, Avus', 'Lag',
#        'Simina Grigoriu', 'Traditional, Gulshan Tandon', 'Big Mojo',
#        'Covenant Worship', 'Dirty Culture, Nusha', 'Dj Marta, Tim Wokan',
#        'Jose Solano, Cafe De Anatolia', 'Bernd Kistenmacher',
#        "Gov't Mule", 'SKYGO', 'Limpodisco, James Rod', 'Bender, Nina',
#        'Valeron, 7even (GR)', 'Elek3ctii', 'Wuta Mayi',
#        'Cosmic Replicant', 'Anna Lee', 'Mijo', 'Boris S.', 'Massa (7)',
#        'Noneoftheabove', 'Cheb Houssem', 'Butcher Brown', 'Prince Rama',
#        'Dj Fudalwokit', 'Green Velvet, Jay Lumen', 'Roger Spees',
#        'Óperentzia', 'Stereo Express', 'bRUNA, Henry Saiz',
#        'Simon Rackham', 'Sincroniza2',
#        'Kim Jens Witzenleiter, Wolfy-Office', 'The Teknoist',
#        'Matt Sassari', 'Joachim Pastor', 'Joachim Pastor', 'Diana Krall',
#        'Mark Michael', 'Nick Magnus', 'Mike Schommer', 'Beatsole',
#        'Michael Sweeney, Midwest Wind Ensemble', 'Eddie Palmieri',
#        'Matador', 'Morgan Heritage', 'Maiga',
#        'Giovanni Battista Pergolesi, Blandine Staskiewicz, Les Ambassadeurs, Alexis Kossenko',
#        'Matt Rowan', 'T-SQUARE', 'The Cinematic Orchestra, Roots Manuva',
#        'Pyotr Ilyich Tchaikovsky, Eugene Ormandy, Philadelphia Orchestra',
#        'Shafa Ullah Khan Rokhri', 'Nga Tae, Paddy Free', 'Exz, Pigmalião',
#        'Nils Ohrmann', 'Gallery Six', 'Danny Cruz, HP Vince',
#        'Michal Prokop, Framus Five', 'Ava Irandoost', 'LM1',
#        'Laika & Strelka', 'Sweet Little Band', 'Lunatica',
#        'Pacific State, Neil Curtis',
#        'Ernesto Köhler, Denis Lupachev, Natalia Frolova',
#        'Ceega Wa Meropa, Rony M, Petmuso', 'Filterheadz', 'Alma Negra',
#        'Agreen Dilshad', 'Neurotribe', 'Audiophonic', 'Maik Thomas',
#        'Andres Blows, Pablo Say', 'RezQ Sound', 'Takuya Matsumoto',
#        'Lightform, Zaa',
#        'Pelle Gudmundsen-Holmgreen, Theatre Of Voices, Paul Hillier',
#        'Devi Chitralekha', 'Maximiljan, Black Loops',
#        'Ludwig van Beethoven, Martha Argerich, Julian Rachlin, Mischa Maisky',
#        'Daniel Bortz', 'Rene Amesz', 'Matthew Lien',
#        'Kooky, Damoon, Niki Kand', 'Rothko',
#        'Traditional, Virginia Band and Orchestra Directors Association 2019 District XI All-District Concert Band, Dr. Brendan Caldwell',
#        'Suara', 'Karanyi', 'Woo2Tech, Sensekraft', 'Fernando Velázquez',
#        'NMR Digital', 'Neil Diamond', 'European Jazz Trio',
#        'Jamie Trench', 'Libertad Maestro', 'Tasya Rosmala', 'S.P.Y',
#        'SeamlessR', 'Lewis Boardman', 'Dj Darroo', 'Olivier C',
#        'Healing Peace', 'Art Department', 'Ralph Kaminski', 'Rubix Qube',
#        'Messenger', 'Tamas Skafar', 'เพลงนวดไทย', 'Borrowed Identity',
#        'Juan Pacifico, Rik-Art, Josephine Sweett, Bruno Kauffmann',
#        'Los Kikers de Carora', 'Furney', 'Belako', 'Omar Jr',
#        'Abdulla Rashim', 'Nexus', 'The Cyclist Conspiracy',
#        'Martin Merino, SOLDIERBEAT, Billy G', '生祥樂隊', 'Lea Cristina',
#        'Answer Code Request', 'Simple Symmetry', 'Visage', 'Trooper',
#        'Michael Wong', 'Stradivarius', 'Meditationsmusik Doktor',
#        'Phonique, Lazarusman, Douglas Greed', 'Lastraw, JazzyFunk',
#        'Supacooks',
#        'Ludwig van Beethoven, Marek Janowski, WDR Sinfonieorchester Köln',
#        'Mason Maynard', 'Róisín Murphy', 'Novalima', 'Felo',
#        'Sidekick, Daniele Petronelli, Worp', 'Nora En Pure',
#        'Mr. Pepper, So.young, Bu.Di', 'Training Motivation Music',
#        'PornoGraffitti', 'Hijjaz', 'natural/electronic.system.',
#        'Paul Hindemith, Xi Zhai, Kronberg Academy Soloists, Schleswig-Holstein Festival Orchestra, Christoph Eschenbach',
#        'Crystal Geometry', 'DJ Nasty 2', 'The Ðevil & the Uñiverse',
#        'Tamara Weber', 'Ital, Aurora Halal', 'Andy Parsons',
#        'Ripe, Audiotree', 'East End Dubs, Enzo Siragusa',
#        'Pr Chandra Sekaran', 'Güç Başar Gülle',
#        'Baal Gopal, Rudhav Sharma', 'Libny Kattapuram, Celine Shoji',
#        'Humanature, j:logic, MC ASTRO', 'Nigel Good',
#        'Dakar, Tim Baresko', 'Zikri', 'Bela Shende', 'amazarashi',
#        'Midhu Vincent', 'Uncovering Within', 'Terraròss', 'Manilla Road',
#        'Masajes Spas, Mantra para Dormir', 'Bomb Squad Unit',
#        'Papi Sousa', 'Dave Anthony, Beverlei Brown', 'Suara',
#        'Madonna, Swae Lee, DJLW', 'Varhat', 'Karim Kamar',
#        'Danniel selfmade', 'Sweet Dreams', 'Harris Jayaraj, Karthik',
#        'Hirntot Posse, Dimi de la Ghetto', 'Christian Ciotola', 'Fine乐团',
#        'GranDiosas, La Sonora Dinamita, Rocio Banquells, Dulce, Manoella Torres',
#        'Popolo Vascio', 'Camouflage', 'Poschek', 'Forest On Stasys',
#        'Yash Chopra, Lata Mangeshkar, Sonu Nigam', 'Sadistics',
#        'Umwelt, The Exaltics', 'Phonotronic', 'Atjazz, Jullian Gomes',
#        'Dennis Cruz, Iuliano Mambo', 'Da Fresh, Max Freegrant, Slow Fish',
#        'Antonello Venditti, Carlo Verdone', 'Kei', 'Luca Debonaire',
#        'La Gossa Sorda', 'The Protomen', 'Tam Ca Áo Trắng',
#        'FM de Zacapa', 'Hans Zimmer, Rupert Gregson-Williams',
#        'Heavenchord', 'Om Meditation Bell', 'Glitter, R3ckzet',
#        'Yvonne Curtis', 'The Unplugged Acoustics', 'Nolek',
#        'Nasta Super, Chris Cain', 'Yoga World', 'Annorkoth',
#        'Bob Reynolds', 'David Forbes, Richard Durand',
#        'Bohemia Suburbana', 'Anoraak', 'Ofdrykkja',
#        'Herr Lounge Corps, Cadaverous Condition', 'Robert Broadway',
#        'Don J Stephen', 'Yaw Sarpong, Asomafo',
#        'Traditional, Tamara Lukasheva, East Drive', 'City', 'Sub Love',
#        'Eli Escobar, Nomi Ruiz', 'Aaron Ahrends', 'The Breathing Effect',
#        'Jennifer Munday', 'Author & Punisher',
#        'Forever Philly Records, Qui$e Limye', 'Kwartz',
#        'Paul Jackson, Xantone Blacq, Tony Match',
#        'Black Loops, Maik Yells', 'Smooth Jazz Saxophone Band', 'Polymod',
#        'Esmerine', 'Geila Zilkha', "Parallax '48",
#        'Eric Alexander Quartet', 'Johnny Bass', 'Paul De Silva', 'w.y.k',
#        'DJ Memo', 'Dendera', 'Davide Mazzilli', 'Manu Kenton',
#        'Kingdom Culture Worship', 'Elkhorn', 'Kizzmo', 'Stiver',
#        'Afrobeat, Tenisara, Nikitin', 'Grand River', 'Andy Hunter',
#        'Streetlights', 'Paloma San Basilio',
#        'Embat Prodz, Miki Leris, Alberto Casallo', "DJ ''S''",
#        'Ara Malikian, La Banda', 'Ely Guerra', '烏野薰爵士樂團', 'Yury Ivánov',
#        'Joseph Tivafire, The House of Blessings', 'Chioma Jesus',
#        'Takuya Nakamura', 'Anthony Mea', 'Lady Zamar', 'ASP',
#        'Terrence Parker', 'Gypsy and the Acid Queen',
#        'Sorinel de la Plopeni', 'Engin Titiz', 'Lady Lizard',
#        'Carter Vail', 'Mama Schultz', 'Krippsoulisc', 'Stolas',
#        'Franco Albertini', 'Moonlight Jazz Blue', 'Alex Haas', 'Daze',
#        'Tomohiko Sagae', 'The Brecker Brothers', 'Modd',
#        'Tm Zaiko, Nuco, Zaiko y Nuco, Flaco, J Alexis, Griser Nsr, Hopper',
#        'Auktyon', 'Huminal', 'Ross Couch', 'Consecration',
#        'Warren Haynes, Derek Trucks', "Peru Inka's", 'Maxim Vilarri',
#        'Future Usses', 'Iñaki Arakistain', 'Rolling Contact',
#        'Blair French', 'Adryiano', 'Dave Z', 'Passion, Kristian Stanfill',
#        'ALBATOROS', 'DJ CON-T', 'Laura Taylor', 'The Irish Rovers',
#        "Gabriel D'Or, Bordoy", 'The New Division, Luke Chable',
#        'Zach Winters', 'LOUDNESS', 'Al Sheikh Maher Al Muaiqly',
#        'Lisa Lynne, Aryeh Frankfurter', 'Remi Collins',
#        'Joey Negro, Dave Lee, The Sunburst Band, Diane Charlemagne, Donna Gardier',
#        'Sebastian Krieg', 'Sarah McSweeney', 'Andrea', 'Wo Fat',
#        'Cab Drivers', 'Kery James, Anissa Stili', 'Saphileaum',
#        'Billy Esteban, Cafe De Anatolia', 'Haydar Öztürk', 'Yougaslava',
#        'Mage', 'Tino',
#        'Harris Jayaraj, Dhanush, Marana Gana Viji, Naveen Madhav',
#        'Sax Gordon', 'Chicane', 'The Transhumans', 'Stamina',
#        'Cindy Blackman Santana, John McLaughlin', 'Race to Space',
#        'Accept', 'fhána', 'Slam', 'Nasteexo Indho', 'Swami Tejomayananda',
#        'Decadawn', 'Keith Fortune, James Mac', 'Young, Gladys',
#        'The Silver Dimes', '２８１４', 'Joyita',
#        'Timmy Regisford, Felicia Graham, Tiger Wilson',
#        'Quentin Dujardin, Didier Laloy', 'Hartmann',
#        'Tài Nguyễn, Hoàng Anh', 'Loud Harp', 'Deadbeat UK',
#        'Garrett David', 'Ex Deo',
#        'Edmund Hartsch, Ben Becker, Böhse Onkelz', 'Chakra Dream',
#        'Killbox', 'The Juggernauts', 'The Life Journey',
#        'Lazarito Valdés y Bamboleo', 'El Búho', 'Planetself', 'BLUEBETTO',
#        'Paul Wilbur', 'La Kritika', 'Pet Music Academy', 'Brandhärd',
#        'David Gravell, Ruby Prophet', 'Replicant',
#        'Skatebård, Lauer, Crabsticks, Igor Tipura', 'Elfendy Tedja',
#        'Pamungkas, The PeoplePeople', 'SOUND HOLIC, Nana Takahashi',
#        'Rosetta Stone', 'Papa Grows Funk', 'UMEMIRU', 'globe',
#        'Lika Morgan, C-Ro', 'Void Vision', 'FT-17', 'Bungle', 'Hamradun',
#        'Lukas De Vrie', 'Howling, Frank Wiedemann, RY X', 'Andy Mientus',
#        'Shakuntala Jadhav', 'Tru Comers, Residentes, La Base',
#        'Campursari Sangga Buana, Wulandari, Putri, Suji',
#        'Roberto Choque, Romanza "La Magia del Sentimiento"', 'Sandi Thom',
#        'LAMP IN TERREN', 'Joji Hirota Taiko Drummers',
#        'AnnaMaria Bergqvist', 'AWeX', "Ge'La", 'Hexell, Sixtho, Freyer',
#        'Valery Teashler', 'Ежемесячные', 'Mike Champion, EarthQuake',
#        'Amaya', 'Chris Rea', 'Banda La Fugitiva De Mike Miramontes',
#        'Saison', 'Angaleena Presley', '天音', 'Yoshiyuki Osawa', 'Hot Chip',
#        'YUZU, SEKAI NO OWARI', 'Rev. John Vijey',
#        'Хор Сретенского монастыря', 'Elvy Sukaesih', 'Waa Wei',
#        'Ana Popovic', 'Natal', 'Karen Davis', 'Kotiteollisuus',
#        'Giacinto Schiatti, Raffaele Trevisani, Ensemble Barocco Carlo Antonio Marino, Natale Arnoldi',
#        'Antoine Forqueray, Atsushi Sakai, Christophe Rousset, Marion Martineau, Isabelle Saint-Yves',
#        'Subalpine', 'Los Violines de Villafontana', 'Mezzo Piano',
#        'RW l est temps de dormir profondément', 'Fucking Werewolf Asso',
#        'Helena Vondráčková', 'Minimusicman', 'Berceuse Academie',
#        'Red Dirt', 'Mahasneh', 'Sentya Sapulette',
#        'Егор и Наталия Лансере',
#        'George Frideric Handel, Josep Maria Martí Duran',
#        'Lang Lang, Andra Day', 'K. S. Harisankar, Shreya Ghoshal, Kailas',
#        'daigoro789', 'Spin Doctors',
#        'Orlande de Lassus, Die Singphoniker', 'Saccao, Gorkiz',
#        'DJ Tira, Black Motion, Drumetic Boyz', 'Zwe Htet',
#        'Amanda Larson',
#        'Johan Daniel Berlin, Gottfried Von Der Goltz, Norwegian Baroque Orchestra',
#        '中山美穂', '鄭興', 'Francisco Tárrega, Giulio Tampalini', 'Paula Menga',
#        'Mickey Cora Y Su Orquesta Cábala', 'Pichy Valdés, Saoco Son',
#        '陳永淘', 'Re-TROS, Liars', 'Beta 2, Steo', 'Windhand',
#        'Luis Miguel Del Amargue',
#        'Allan Taylor, Michael Koschorrek, Ralf Gustke, Hans-Joerg Maucksch, Dieter Burmester, Michael Kleinhans',
#        'Johann Sebastian Bach, Nicholas Danby', 'Calibre', 'Novelbright',
#        'Alexander Broussard', 'Wilki',
#        'Johann Sebastian Bach, English Baroque Soloists, John Eliot Gardiner',
#        'Yuki Ijuin, CARREC', 'Pongsit Kampee', 'The Vintage Vandals',
#        'Camilla Sparksss', 'Christmas Hits Collective',
#        "Christine D'Clario", 'Tangerine Dream', 'Suncatcher',
#        'Murat Yalçın', 'MIGYO', 'Tim Dian',
#        'Pure Obsessions & Red Nights, An Erotic End of Times',
#        'Fariborz Lachini', 'LaCrême, Ladybird', 'Manatsu Nagahara',
#        'Fox Amoore', 'Leo Brouwer, Sharon Isbin', 'Alex Verdugo',
#        'Lazuli', 'Hoài Lâm', 'Pete Bellis & Tommy, Costa Mee',
#        'Matt Doyle', 'Relaxing Mindfulness Meditation Relaxation Maestro',
#        'Ringbaan', 'Kibariye', 'Bernard Allison',
#        'Aretha Franklin, Papercha$Er', 'Jacksonifyer',
#        'Bouzouki Kings, Giorgos Zambetas', 'Kiki Doll, Luca Debonaire',
#        'Massage Therapy Studio', 'Sweet Charity',
#        'Gáspár Kálmán Leon, Khamoro Budapest Band', 'Solomon Grey',
#        'Gammalgrass', 'Uptown Vocal Jazz Quartet, Richie Cole',
#        'Nicu Mâță, Paul Ananie, Gabriel Dumitru, Orchestra Lăutarii',
#        'Orien', 'Roy y Los Gentiles Oficial', 'NNS', 'Khaled Abdrabo',
#        'Marc Hartman', 'Joris Voorn, Kid A', 'Celtas Cortos, Nomadi',
#        '同心圓‧敬拜者使團TWS', 'Jeff Pierre', 'Sammi Cheng, David Ling Jr',
#        'Nao Matsushita', 'Orchestre de la fin du monde',
#        'Chad Michael Butler, Yuna Kim', 'Bi-2', '遠見真矢(CV:松本まりか)',
#        'Elder Anthony Boachie, Great Ampong', 'Hilary Woods',
#        'Shams, Muboraksho Mirzoshoev', 'David Tavares, André Ribas',
#        'Stephanie Erastus', 'Buleria', 'Cezinando, Chirag', 'Darkthrone',
#        'DJ Antoine, Armando, Jimmi The Dealer, Groove81', 'Trygve Skaug',
#        'Sinister Skeletons', 'Scheherazade', 'Arnaud Rebotini',
#        'Evgeny Nazarenko', 'Olavi Uusivirta', 'Coakira',
#        'Dawn Tyler Watson, Ben Racine',
#        'Daniele De Martino, Valentina Belli', 'Timothy James Bowen',
#        'Ale Möller, Lena Willemark, Hans Ek, Västerås Sinfonietta, Rafael Sida Huizar',
#        'Riverdale Cast, Camila Mendes, Cole Sprouse, KJ Apa, Lili Reinhart',
#        'Accuface', 'Lucinda Williams', 'Noemi Huamán', 'KLANGSTEIN',
#        'Marno ASMR', 'Mark Barrott', 'Đan Trường',
#        'Carlos Gallardo & Peyton', 'Борис Акунин', 'Kjell Inge Torgersen',
#        'The Haggis Horns, Doc Brown', 'Petrona Gonzales',
#        'Neno Belan, Fiumens', 'Keni Rightout',
#        'Honey Colonna, Highway Superstar', 'Dorsaf Hamdani',
#        'Simfònica de Cobla i Corda de Catalunya, Manu Guix, Elena Gadel',
#        'ASMR Glow', 'İbrahim Can', 'Chandimal Fernando, Mahi Pasquel',
#        'Teresa Parodi', 'Diana Gabaldon, Birgitta Assheuer',
#        'Hirai Zerdüş', 'El Remolón', 'Dore', 'Retief Burger',
#        'Yukiko Okada', 'Dave Gahan',
#        'Lluís Coloma Trio, Lluís Coloma, Manolo Germán, Marc Ruiz',
#        'Electric Dragon', '西木野真姫(CV.Pile)', 'Vagina Lips',
#        'Jacana Jacana', 'Radnor', 'EAMONN KARRAN', 'Dorel de la Popesti',
#        'Pilot', 'Haleiwa', 'Ngọc Hân', 'Kobosil', '阿尾茂毅',
#        'Daniel Aguayo, Regan', 'Marcio Teixeira, Coral Voice Soul',
#        'Brandon Echavarria, legado, Solangie Rodriguez, Alto Destino, Andrés Guerrero, Angie Ramirez, Antonella Guerrero, Carlos Hurtado, Leydy Ulcue, Maria Camila Novoa, Sara Novoa, Valery Guerrero',
#        'Compay Segundo', 'The Synthphonix', 'Füstös', 'Ato Libertário',
#        'Yamaoka', 'Haydée Milanés, Kelvis Ochoa', 'Cotton Claw',
#        '玻璃海樂團, Airy Chan, Gabby Yeung', 'Dope D.O.D.', 'Ада',
#        'Julio Elias', 'Arno Strobel, Sascha Rotermund', 'Alfa Sekta',
#        'MoshTekk', 'Ventre', 'Miltatek', 'Mashina Vremeni',
#        'Acoustic Heartstrings', 'Marc Anthony', "James Brown, The J.B.'s",
#        'Andreas Waldetoft', 'Zion Worship, Pauli Salas', 'Low Deep T',
#        'Ty Ardis, Albert Lennard Project',
#        'Gruselkabinett, Michael Pan, Matthias Lühn, Horst Naumann, Claudia Urbschat-Mingues, Hanns Heinz Ewers',
#        'Workout Dance Factory', 'Dexter Ward', 'Sideform, Sonic Entity',
#        'Ana Consejos, Musica Relajante',
#        'Krafty Kuts, Dynamite MC, Chali 2na, Kraak & Smaak',
#        'Mozes and the Firstborn', 'Dana Gillespie',
#        'Ylli Demaj, Adelina Tahiri, Ryva Kajtazi', 'Mors Principium Est',
#        'Yuuki Okamoto', 'Terri Geisel',
#        'Michael Dease, Tim Green, Glenn Zaleski, Rodney Whitaker, Ulysses Owens',
#        'Entspannungszeit', 'Chimpo, DRS, Slay, Rago Loco',
#        'The Sleeping Tree, Niam', 'Jeffrey Paradise', 'Ungdomskulen',
#        '歌っちゃ王', 'Adoro', 'Sandy Turnbull', 'Search', 'Counting Clouds',
#        'Relaxing Orgel', 'La Pitufobanda', 'UNCHAIN', 'Thu Uyên',
#        'Mahesa', 'Chiki Liki Tu-a', 'Gregory Isaacs',
#        'JayRex SuiSui, Jharvii, Robby T', 'Mãeana', 'Vanilla', 'Re:Lilly',
#        'Jana Rychterová', 'Baby Band', 'Mellina'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.8)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ffe3bb4e24ad> in <cell line: 1>()
# ----> 1 x_train = sc.fit_transform(x_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
#     880             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     822         # Reset internal state before fitting
#     823         self._reset()
# --> 824         return self.partial_fit(X, y, sample_weight)
#     825
#     826     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     859
#     860         first_call = not hasattr(self, "n_samples_seen_")
# --> 861         X = self._validate_data(
#     862             X,
#     863             accept_sparse=("csr", "csc"),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# ValueError: could not convert string to float: '4VWH8rEUBZWmxKNHpSupiO'

# %%
x_test = sc.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-18-4aa16f5d44c8> in <cell line: 1>()
# ----> 1 x_test = sc.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#     987             Transformed array.
#     988         """
# --> 989         check_is_fitted(self)
#     990
#     991         copy = copy if copy is not None else self.copy
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1388
#    1389     if not fitted:
# -> 1390         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1391
#    1392
#
# NotFittedError: This StandardScaler instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-b2fdb00a4f45> in <cell line: 3>()
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 classifier = KNeighborsClassifier(n_neighbors=5)
# ----> 3 classifier.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     474                     self.outputs_2d_ = True
#     475
# --> 476                 check_classification_targets(y)
#     477                 self.classes_ = []
#     478                 self._y = np.empty(y.shape, dtype=int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     216         "multilabel-sequences",
#     217     ]:
# --> 218         raise ValueError("Unknown label type: %r" % y_type)
#     219
#     220
#
# ValueError: Unknown label type: 'continuous'
