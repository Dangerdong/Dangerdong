# %%
def firstlast(sequence):
  return sequence[0] + sequence[-1]

# %%
firstlast(('a','b','c'))
# Out:
# 'ac'

# %%
def firstlast(sequence):
  return sequence[0] , sequence[-1]

# %%
firstlast(['a','b','c'])
# Out:
# ('a', 'c')
